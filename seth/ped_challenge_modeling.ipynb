# %% [markdown]
# # Pediatric Sepsis Challenge Notebook - Modeling
#
# ## Tasks still to do
#
# * Split data into train/test
# * K-fold cross validation?
# * Determine modeling methods to try
#   * XGBoost to start
#   * Phoenix scores
# * Feature selection (Forward selection?)
