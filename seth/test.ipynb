# %%
import pandas as pd
import numpy as np

# %%
dfpd = pd.read_csv('https://github.com/magic-lantern/The-2024-Pediatric-Sepsis-Challenge/raw/refs/heads/main/SyntheticData_Training.csv', low_memory=False)
dfpd
# Out:
#       studyid_adm  agecalc_adm  height_cm_adm  weight_kg_adm  muac_mm_adm  \
# 0               1         16.8           79.8           11.6        150.0
# 1               2         46.1           93.0           13.6        151.0
# 2               3          7.9           68.2            8.2        148.0
# 3               4         38.2           95.0           12.0        138.0
# 4               5         16.1           83.0           12.0        165.0
# ...           ...          ...            ...            ...          ...
# 2681         2682         20.1           98.2           10.0        135.0
# 2682         2683         26.8           82.3           10.0        140.0
# 2683         2684         14.6           82.4           12.7        145.0
# 2684         2685          9.5           67.5            7.5        130.0
# 2685         2686         11.3           77.8            8.0        131.0
#
#       hr_bpm_adm  rr_brpm_app_adm  sysbp_mmhg_adm  diasbp_mmhg_adm  \
# ...

# %%
pd.read_csv('../SyntheticData_Training.csv', low_memory=False)
# Out:
#       studyid_adm  agecalc_adm  height_cm_adm  weight_kg_adm  muac_mm_adm  \
# 0               1         16.8           79.8           11.6        150.0
# 1               2         46.1           93.0           13.6        151.0
# 2               3          7.9           68.2            8.2        148.0
# 3               4         38.2           95.0           12.0        138.0
# 4               5         16.1           83.0           12.0        165.0
# ...           ...          ...            ...            ...          ...
# 2681         2682         20.1           98.2           10.0        135.0
# 2682         2683         26.8           82.3           10.0        140.0
# 2683         2684         14.6           82.4           12.7        145.0
# 2684         2685          9.5           67.5            7.5        130.0
# 2685         2686         11.3           77.8            8.0        131.0
#
#       hr_bpm_adm  rr_brpm_app_adm  sysbp_mmhg_adm  diasbp_mmhg_adm  \
# ...

# %%
# !pip install polars
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 114.7 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import polars as pl

# %%
dfpl = pl.read_csv('https://github.com/magic-lantern/The-2024-Pediatric-Sepsis-Challenge/raw/refs/heads/main/SyntheticData_Training.csv', infer_schema_length=1000000)
dfpl
# Out:
# shape: (2_686, 140)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ studyid_a ┆ agecalc_a ┆ height_cm ┆ weight_kg ┆ … ┆ malariast ┆ lengthadm ┆ caregiver ┆ inhospit │
# │ dm        ┆ dm        ┆ _adm      ┆ _adm      ┆   ┆ atuspos_a ┆ ---       ┆ _adm_new  ┆ al_morta │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ dm        ┆ i64       ┆ ---       ┆ lity     │
# │ i64       ┆ f64       ┆ str       ┆ str       ┆   ┆ ---       ┆           ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 1         ┆ 16.8      ┆ 79.8      ┆ 11.6      ┆ … ┆ No        ┆ 2         ┆ Mother    ┆ 0        │
# │ 2         ┆ 46.1      ┆ 93        ┆ 13.6      ┆ … ┆ Yes       ┆ 5         ┆ Mother    ┆ 0        │
# ...

# %%
pl.read_csv('../SyntheticData_Training.csv',
            low_memory=False,
            null_values=['NA'],
            infer_schema_length=100000
           )
# Out:
# shape: (2_686, 140)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ studyid_a ┆ agecalc_a ┆ height_cm ┆ weight_kg ┆ … ┆ malariast ┆ lengthadm ┆ caregiver ┆ inhospit │
# │ dm        ┆ dm        ┆ _adm      ┆ _adm      ┆   ┆ atuspos_a ┆ ---       ┆ _adm_new  ┆ al_morta │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ dm        ┆ i64       ┆ ---       ┆ lity     │
# │ i64       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ ---       ┆           ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 1         ┆ 16.8      ┆ 79.8      ┆ 11.6      ┆ … ┆ No        ┆ 2         ┆ Mother    ┆ 0        │
# │ 2         ┆ 46.1      ┆ 93.0      ┆ 13.6      ┆ … ┆ Yes       ┆ 5         ┆ Mother    ┆ 0        │
# ...
